# %%
import pandas as pd
from pprint import pprint
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

from resources.api_keys import census_api_key

# %%
pprint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-6c5fe9e3ea97> in <module>
# ----> 1 pprint()
#
# TypeError: pprint() missing 1 required positional argument: 'object'

# %%
censusdata.printtable(censusdata.censustable('acs5', 2018, 'B24041'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B24041_001E  | INDUSTRY BY MEDIAN EARNINGS IN | !! Estimate Total                                        | int
# B24041_002E  | INDUSTRY BY MEDIAN EARNINGS IN | !! !! Estimate Total Agriculture, forestry, fishing and  | int
# B24041_003E  | INDUSTRY BY MEDIAN EARNINGS IN | !! !! !! Estimate Total Agriculture, forestry, fishing a | int
# B24041_004E  | INDUSTRY BY MEDIAN EARNINGS IN | !! !! !! Estimate Total Agriculture, forestry, fishing a | int
# B24041_005E  | INDUSTRY BY MEDIAN EARNINGS IN | !! !! Estimate Total Construction                        | int
# B24041_006E  | INDUSTRY BY MEDIAN EARNINGS IN | !! !! Estimate Total Manufacturing                       | int
# ...

# %%
states = censusdata.geographies(censusdata.censusgeo([('state', '*')]), 'acs5', 2018)
pprint(states)
# Out:
# {'Alabama': censusgeo((('state', '01'),)),
#  'Alaska': censusgeo((('state', '02'),)),
#  'Arizona': censusgeo((('state', '04'),)),
#  'Arkansas': censusgeo((('state', '05'),)),
#  'California': censusgeo((('state', '06'),)),
#  'Colorado': censusgeo((('state', '08'),)),
#  'Connecticut': censusgeo((('state', '09'),)),
#  'Delaware': censusgeo((('state', '10'),)),
#  'District of Columbia': censusgeo((('state', '11'),)),
#  'Florida': censusgeo((('state', '12'),)),
#  'Georgia': censusgeo((('state', '13'),)),
#  'Hawaii': censusgeo((('state', '15'),)),
#  'Idaho': censusgeo((('state', '16'),)),
#  'Illinois': censusgeo((('state', '17'),)),
#  'Indiana': censusgeo((('state', '18'),)),
#  'Iowa': censusgeo((('state', '19'),)),
#  'Kansas': censusgeo((('state', '20'),)),
#  'Kentucky': censusgeo((('state', '21'),)),
#  'Louisiana': censusgeo((('state', '22'),)),
#  'Maine': censusgeo((('state', '23'),)),
#  'Maryland': censusgeo((('state', '24'),)),
# ...

# %%
counties = censusdata.geographies(censusdata.censusgeo([('state', '29'), ('county', '*')]), 'acs5', 2018)
pprint(counties)
# Out:
# {'Adair County, Missouri': censusgeo((('state', '29'), ('county', '001'))),
#  'Andrew County, Missouri': censusgeo((('state', '29'), ('county', '003'))),
#  'Atchison County, Missouri': censusgeo((('state', '29'), ('county', '005'))),
#  'Audrain County, Missouri': censusgeo((('state', '29'), ('county', '007'))),
#  'Barry County, Missouri': censusgeo((('state', '29'), ('county', '009'))),
#  'Barton County, Missouri': censusgeo((('state', '29'), ('county', '011'))),
#  'Bates County, Missouri': censusgeo((('state', '29'), ('county', '013'))),
#  'Benton County, Missouri': censusgeo((('state', '29'), ('county', '015'))),
#  'Bollinger County, Missouri': censusgeo((('state', '29'), ('county', '017'))),
#  'Boone County, Missouri': censusgeo((('state', '29'), ('county', '019'))),
#  'Buchanan County, Missouri': censusgeo((('state', '29'), ('county', '021'))),
#  'Butler County, Missouri': censusgeo((('state', '29'), ('county', '023'))),
# ...

# %%
tracts = censusdata.geographies(censusdata.censusgeo([('state', '29'), ('county', '189'), ('tract', '*')]), 'acs5', 2018)
pprint(tracts)
# Out:
# {'Census Tract 2101, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210100'))),
#  'Census Tract 2102, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210200'))),
#  'Census Tract 2103, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210300'))),
#  'Census Tract 2104, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210400'))),
#  'Census Tract 2105.01, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210501'))),
#  'Census Tract 2105.02, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210502'))),
#  'Census Tract 2106, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210600'))),
#  'Census Tract 2107.02, St. Louis County, Missouri': censusgeo((('state', '29'), ('county', '189'), ('tract', '210702'))),
# ...

# %% [markdown]
# ## Industry By Median Earnings In The Past 12 Months (In 2018 Inflation-Adjusted Dollars) For The Civilian Employed Population 16 Years And Over ##

# %%
df189 = censusdata.download('acs5', 2018,
                        censusdata.censusgeo([('state', '29'), ('county', '189'), ('tract','*')]),
                        ['B24031_002E', 'B24031_005E', 'B24031_006E', 'B24031_007E', 'B24031_008E'
                        ,'B24031_009E', 'B24031_012E', 'B24031_013E', 'B24031_016E', 'B24031_020E'
                        ,'B24031_023E', 'B24031_026E', 'B24031_027E'],
                        census_api_key,
                        'detail')

# %%
df510 = censusdata.download('acs5', 2018,
                        censusdata.censusgeo([('state', '29'), ('county', '510'), ('tract','*')]),
                        ['B24031_002E', 'B24031_005E', 'B24031_006E', 'B24031_007E', 'B24031_008E'
                        ,'B24031_009E', 'B24031_012E', 'B24031_013E', 'B24031_016E', 'B24031_020E'
                        ,'B24031_023E', 'B24031_026E', 'B24031_027E'],
                        census_api_key,
                        'detail')

# %%
col_names = ["Agriculture, forestry, fishing and hunting, and mining"
            ,"Construction"
            ,"Manufacturing"
            ,"Wholesale trade"
            ,"Retail trade"
            ,"Transportation and warehousing, and utilities"
            ,"Information"
            ,"Finance and insurance, and real estate, and rental and leasing"
            ,"Professional, scientific, and management, and administrative, and waste management services"
            ,"Educational services, and health care and social assistance"
            ,"Arts, entertainment, and recreation, and accommodation and food services"
            ,"Other services, except public administration"
            ,"Public administration"]

# %%
df189.columns = col_names
df510.columns = col_names

# %%
df189
# Out:
#                                                     Agriculture, forestry, fishing and hunting, and mining  Construction  Manufacturing  Wholesale trade  Retail trade  Transportation and warehousing, and utilities  Information  Finance and insurance, and real estate, and rental and leasing  Professional, scientific, and management, and administrative, and waste management services  Educational services, and health care and social assistance  Arts, entertainment, and recreation, and accommodation and food services  Other services, except public administration  Public administration
# ...

# %%
df510
# Out:
#                                                     Agriculture, forestry, fishing and hunting, and mining  Construction  Manufacturing  Wholesale trade  Retail trade  Transportation and warehousing, and utilities  Information  Finance and insurance, and real estate, and rental and leasing  Professional, scientific, and management, and administrative, and waste management services  Educational services, and health care and social assistance  Arts, entertainment, and recreation, and accommodation and food services  Other services, except public administration  Public administration
# ...
