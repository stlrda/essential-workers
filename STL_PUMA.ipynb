280&INDP=7290&INDP=7370&INDP=7380&INDP=7390&INDP=7460&INDP=7470&INDP=7480&INDP=7490&INDP=7570&INDP=7580&INDP=7590&INDP=7670&INDP=7680&INDP=7690&INDP=7770&INDP=7780&INDP=7790&INDP=7860&INDP=7870&INDP=7880&INDP=7890&INDP=7970&INDP=7980&INDP=7990&INDP=8070&INDP=8080&INDP=8090&INDP=8170&INDP=8180&INDP=8191&INDP=8192&INDP=8270&INDP=8290&INDP=8370&INDP=8380&INDP=8390&INDP=8470&INDP=8561&INDP=8562&INDP=8563&INDP=8564&INDP=8570&INDP=8580&INDP=8590&INDP=8660&INDP=8670&INDP=8680&INDP=8690&INDP=8770&INDP=8780&INDP=8790&INDP=8870&INDP=8891&INDP=8970&INDP=8980&INDP=8990&INDP=9070&INDP=9080&INDP=9090&INDP=9160&INDP=9170&INDP=9180&INDP=9190&INDP=9290&INDP=9370&INDP=9380&INDP=9390&INDP=9470&INDP=9480&INDP=9490&INDP=9570&INDP=9590&INDP=9670&INDP=9680&INDP=9690&INDP=9770&INDP=9780&INDP=9790&INDP=9870&INDP=9920'
geo = '&ucgid=7950000US2901801,7950000US2901802,7950000US2901803,7950000US2901804,7950000US2901805,7950000US2901806,7950000US2901807,7950000US2901808,7950000US2901901,7950000US2901902'

# %%
Grocery_Convenience_DrugStores = ['4470', '4971', '4972', '5070', '5391']
Public_Transit = ['6080', '6180']
Trucking_Warehouse_PostalService = ['6170', '6390', '6370']
Building_Cleaning_Services = ['7690']
Health_Care = ['7970', '8090', '8170', '8180', '8191', '8192', '8270', '8290']
ChildCare_SocialServices = ['8370', '8380', '8470']

frontline_industries = Grocery_Convenience_DrugStores + Public_Transit + Trucking_Warehouse_PostalService + Building_Cleaning_Services + Health_Care + ChildCare_SocialServices

# %%
def convert_industry_codes(df):
    df.replace(to_replace = {'4470':'Convenience_Stores', '4971':'Convenience_Stores', '4972':'Convenience_Stores', '5070':'Convenience_Stores', '5391':'Convenience_Stores'
                                         ,'6080':'Public_Transit', '6180':'Public_Transit'
                                         ,'6170':'Postal_Service', '6390':'Postal_Service', '6370':'Postal_Service'
                                         ,'7690':'Building_Cleaning'
                                         ,'7970':'Health_Care', '8090':'Health_Care', '8170':'Health_Care', '8180':'Health_Care', '8191':'Health_Care', '8192':'Health_Care', '8270':'Health_Care', '8290':'Health_Care'
                                         ,'8370':'Child_Care', '8380':'Child_Care', '8470':'Child_Care'}
                   , value = None
                   , inplace = True)
    return df

# %%
# df = dataframe passed in. Should be 2 columns. (var, 'INDP')
# var = lable on column var which contains 2 kinds of values to emulate a boolean 
#    (what matters is that the value for fieldT is less than the value for fieldF)
# fieldT = lable for result column which counts the % of total values in column var where value = fieldT
# fieldF = lable for result column which counts the % of total values in column var where value = fieldF

def format_dataframes(df, var, fieldT, fieldF):

    fieldFp = '% ' + fieldF
    fieldTp = '% ' + fieldT
    
    #create dataframe for all industries
    df_all = df.groupby(df[var]).size()
    df_all = df_all.reset_index()
    df_all = df_all.T
    df_all = df_all.rename(columns={0: fieldT, 1: fieldF})
    df_all = df_all.rename(index={0: "All_Industries"})
    df_all = df_all.drop(var)
    df_all['Total'] = df_all[fieldF] + df_all[fieldT]
    
    #create dataframe for all frontline industries
    df = df.loc[df['INDP'].isin(frontline_industries)]
    
    df_front = df.groupby(df[var]).size()
    df_front = df_front.reset_index()
    df_front = df_front.T
    df_front = df_front.rename(columns={0: fieldT, 1: fieldF})
    df_front = df_front.rename(index={0: "Frontline_Industries"})
    df_front = df_front.drop(var)
    df_front['Total'] = df_front[fieldF] + df_front[fieldT]
    
    #create dataframe for specific frontline industries
    convert_industry_codes(df)
    
    df = df.groupby(['INDP', var]).size()
    df = df.unstack(var)
    df.columns=[fieldT, fieldF]
    df.fillna(0, inplace = True)
    df['Total'] = df[fieldF] + df[fieldT]
    
    #combine dataframes
    df_combined = pd.concat([df_all, df_front, df])
    df_combined[fieldFp] = ((df_combined[fieldF] / df_combined['Total']) * 100).apply(lambda x: round(x, 2))
    df_combined[fieldTp] = ((df_combined[fieldT] / df_combined['Total']) * 100).apply(lambda x: round(x, 2))
    df_combined = df_combined.reset_index()
    
    df_final = pd.DataFrame(df_combined[['index', 'Total', fieldTp, fieldFp]])
    df_final.columns = ['Industry', 'Total', fieldTp, fieldFp]
    
    return (df_all, df_front, df, df_final)
    #return (df_final)

# %%
dataframelist = []
for variable in variable_list:
    API_REQUEST = base_url+variable+industries+geo
    get_data = requests.get(API_REQUEST).json()
    df = pd.DataFrame(get_data, columns=get_data.pop(0))
    dataframelist.append(df)

popgender = dataframelist[0]
popage = dataframelist[1]
popinsurance = dataframelist[2]
popsenior = dataframelist[3]
popchild = dataframelist[4]
popwork = dataframelist[5]
poptrans = dataframelist[6]
popfborn = dataframelist[7]
popeduc = dataframelist[8]
popraceblack = dataframelist[9]
popraceother = dataframelist[10]
popracehawaii = dataframelist[11]
popracepacific = dataframelist[12]
popraceasian = dataframelist[13]
popracenative = dataframelist[14]
pophomeowner = dataframelist[15]
poppoverty = dataframelist[16]

# %% [markdown]
# ## Gender (SEX)##

# %%
gender = popgender[['SEX','INDP']]
gender_df = format_dataframes(gender, 'SEX', 'Male', 'Female')
# Out:
# c:\users\kab0320\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4272: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
gender_df[3]
# Out:
#                Industry  Total  % Male  % Female
# 0        All_Industries  34205   49.14     50.86
# 1  Frontline_Industries   7232   33.66     66.34
# 2     Building_Cleaning    267   55.43     44.57
# 3            Child_Care    802   14.46     85.54
# 4    Convenience_Stores   1312   49.70     50.30
# 5           Health_Care   4083   24.74     75.26
# 6        Postal_Service    592   70.61     29.39
# 7        Public_Transit    176   51.14     48.86

# %% [markdown]
# ## Age 50+ (AGEP)##

# %%
age = popage[['AGEP','INDP']]
age['AGEP'] = pd.to_numeric(age['AGEP'])
age.loc[age['AGEP'] < 50, 'AGEP'] = 2
age.loc[age['AGEP'] >= 50, 'AGEP'] = 1
age_df =  format_dataframes(age, 'AGEP', '50+', 'Under 50')
# Out:
# <ipython-input-9-6387acf0ae90>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age['AGEP'] = pd.to_numeric(age['AGEP'])
# c:\users\kab0320\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
age_df[3]
# Out:
#                Industry  Total  % 50+  % Under 50
# 0        All_Industries  34205  41.28       58.72
# 1  Frontline_Industries   7232  42.75       57.25
# 2     Building_Cleaning    267  45.32       54.68
# 3            Child_Care    802  43.27       56.73
# 4    Convenience_Stores   1312  35.21       64.79
# 5           Health_Care   4083  43.06       56.94
# 6        Postal_Service    592  53.89       46.11
# 7        Public_Transit    176  48.30       51.70

# %% [markdown]
# ## Have Insurance (HICOV)##

# %%
insurance = popinsurance[['HICOV','INDP']]
insurance_df =  format_dataframes(insurance, 'HICOV', 'Insured', 'Uninsured')

# %%
insurance_df[3]
# Out:
#                Industry  Total  % Insured  % Uninsured
# 0        All_Industries  34205      92.13         7.87
# 1  Frontline_Industries   7232      91.81         8.19
# 2     Building_Cleaning    267      77.90        22.10
# 3            Child_Care    802      90.77         9.23
# 4    Convenience_Stores   1312      90.47         9.53
# 5           Health_Care   4083      93.73         6.27
# 6        Postal_Service    592      89.70        10.30
# 7        Public_Transit    176      90.34         9.66

# %% [markdown]
# ## Presence of Elder 65+ in household (R65)##

# %%
senior = popsenior[['R65','INDP']]
senior['R65'] = pd.to_numeric(senior['R65'])
senior.loc[senior['R65'] <= 0, 'R65'] = 0
senior.loc[senior['R65'] >= 1, 'R65'] = 1
senior_df =  format_dataframes(senior, 'R65', 'No Seniors', 'Senior (age 65+) in home')
# Out:
# <ipython-input-13-a1f39ee6fd3a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   senior['R65'] = pd.to_numeric(senior['R65'])

# %%
senior_df[3]
# Out:
#                Industry  Total  % No Seniors  % Senior (age 65+) in home
# 0        All_Industries  34205         80.71                       19.29
# 1  Frontline_Industries   7232         79.12                       20.88
# 2     Building_Cleaning    267         76.78                       23.22
# 3            Child_Care    802         74.44                       25.56
# 4    Convenience_Stores   1312         78.28                       21.72
# 5           Health_Care   4083         80.77                       19.23
# 6        Postal_Service    592         78.38                       21.62
# 7        Public_Transit    176         74.43                       25.57

# %% [markdown]
# ## Presence of Child <18 in household (R18)##

# %%
child = popchild[['R18','INDP']]
child['R18'] = pd.to_numeric(child['R18'])
child.drop(child[child['R18'] == -1].index , inplace=True)
child_df =  format_dataframes(child, 'R18', 'No Children < 18', '1+ children')
# Out:
# <ipython-input-15-0c585c828bf6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   child['R18'] = pd.to_numeric(child['R18'])
# c:\users\kab0320\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
child_df[3]
# Out:
#                Industry  Total  % No Children < 18  % 1+ children
# 0        All_Industries  33055               65.69          34.31
# 1  Frontline_Industries   7083               65.86          34.14
# 2     Building_Cleaning    255               67.45          32.55
# 3            Child_Care    789               65.91          34.09
# 4    Convenience_Stores   1271               68.45          31.55
# 5           Health_Care   4009               64.36          35.64
# 6        Postal_Service    583               70.15          29.85
# 7        Public_Transit    176               64.77          35.23

# %% [markdown]
# ## Part time or Full time work (WKHP)##

# %%
work = popwork[['WKHP','INDP']]
work.drop(work[work['WKHP'] == '0'].index , inplace=True)
work['WKHP'] = pd.to_numeric(work['WKHP'])
work.loc[work['WKHP'] < 40, 'WKHP'] = 0
work.loc[work['WKHP'] >= 40, 'WKHP'] = 1
work_df =  format_dataframes(work, 'WKHP', 'Part-Time', 'Full-Time')
# Out:
# <ipython-input-17-7e829311356e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   work['WKHP'] = pd.to_numeric(work['WKHP'])

# %%
work_df[3]
# Out:
#                Industry  Total  % Part-Time  % Full-Time
# 0        All_Industries  30116        31.50        68.50
# 1  Frontline_Industries   6328        36.01        63.99
# 2     Building_Cleaning    222        51.80        48.20
# 3            Child_Care    675        47.85        52.15
# 4    Convenience_Stores   1139        46.80        53.20
# 5           Health_Care   3644        32.57        67.43
# 6        Postal_Service    506        14.03        85.97
# 7        Public_Transit    142        35.21        64.79

# %% [markdown]
# ## Public Transportation (JWTR)##

# %%
trans = poptrans[['JWTR','INDP']]
trans['JWTR'] = pd.to_numeric(trans['JWTR'])
trans.drop(trans[trans['JWTR'] == 0].index , inplace=True)
trans.loc[trans['JWTR'] >= 8, 'JWTR'] = 1
trans.loc[trans['JWTR'] >= 2, 'JWTR'] = 0
trans_df =  format_dataframes(trans, 'JWTR', 'Public Transportation', 'Private Transportation')
# Out:
# <ipython-input-19-b35147a5f1a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trans['JWTR'] = pd.to_numeric(trans['JWTR'])

# %%
trans_df[3]
# Out:
#                Industry  Total  % Public Transportation  % Private Transportation
# 0        All_Industries  26633                     3.65                     96.35
# 1  Frontline_Industries   5671                     4.32                     95.68
# 2     Building_Cleaning    187                     8.02                     91.98
# 3            Child_Care    573                     3.66                     96.34
# 4    Convenience_Stores    987                     4.36                     95.64
# 5           Health_Care   3342                     4.19                     95.81
# 6        Postal_Service    457                     3.06                     96.94
# 7        Public_Transit    125                     9.60                     90.40

# %% [markdown]
# ## Foreign Born (WAOB) ##

# %%
fborn = popfborn[['WAOB','INDP']]
fborn['WAOB'] = pd.to_numeric(fborn['WAOB'])
fborn.loc[fborn['WAOB'] == 2, 'WAOB'] = 1
fborn.loc[fborn['WAOB'] >= 3, 'WAOB'] = 0
fborn_df =  format_dataframes(fborn, 'WAOB', 'Foreign Born', 'Natural Born Citizen')
# Out:
# <ipython-input-21-ef4e50d7f874>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fborn['WAOB'] = pd.to_numeric(fborn['WAOB'])

# %%
fborn_df[3]
# Out:
#                Industry  Total  % Foreign Born  % Natural Born Citizen
# 0        All_Industries  34205            8.50                   91.50
# 1  Frontline_Industries   7232            8.95                   91.05
# 2     Building_Cleaning    267           10.49                   89.51
# 3            Child_Care    802            5.49                   94.51
# 4    Convenience_Stores   1312            7.93                   92.07
# 5           Health_Care   4083            9.89                   90.11
# 6        Postal_Service    592           10.64                   89.36
# 7        Public_Transit    176            2.27                   97.73

# %% [markdown]
# ## Home Ownership/Tenure (TEN) ##

# %%
homeowner = pophomeowner[['TEN', 'INDP']]

# %%
homeowner['TEN'] = pd.to_numeric(homeowner['TEN'])
homeowner.loc[homeowner['TEN'] == 2, 'TEN'] = 1
homeowner.loc[homeowner['TEN'] >= 3, 'TEN'] = 0
homeowner_df =  format_dataframes(homeowner, 'TEN', 'Rent/Squatter', 'Home Owner')
# Out:
# <ipython-input-24-6658dc642f77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   homeowner['TEN'] = pd.to_numeric(homeowner['TEN'])

# %%
homeowner_df[3]
# Out:
#                Industry  Total  % Rent/Squatter  % Home Owner
# 0        All_Industries  34205            29.46         70.54
# 1  Frontline_Industries   7232            34.29         65.71
# 2     Building_Cleaning    267            41.57         58.43
# 3            Child_Care    802            35.66         64.34
# 4    Convenience_Stores   1312            37.12         62.88
# 5           Health_Care   4083            33.06         66.94
# 6        Postal_Service    592            28.38         71.62
# 7        Public_Transit    176            44.32         55.68

# %% [markdown]
# ## Poverty ##

# %%
poverty = poppoverty[['POVPIP','INDP']]

# %%
poverty['POVPIP'] = pd.to_numeric(poverty['POVPIP'])
poverty.drop(poverty[poverty['POVPIP'] == -1].index , inplace=True)
poverty.loc[poverty['POVPIP'] < 100, 'POVPIP'] = 0
poverty.loc[(poverty['POVPIP'] >= 100) & (poverty['POVPIP'] < 200), 'POVPIP'] = 1
poverty.loc[poverty['POVPIP'] >= 200, 'POVPIP'] = 2
# Out:
# <ipython-input-83-10aba6e48ebf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty['POVPIP'] = pd.to_numeric(poverty['POVPIP'])

# %%
poverty_all = poverty.groupby(poverty['POVPIP']).size()
poverty_all = poverty_all.reset_index()
poverty_all = poverty_all.T
poverty_all = poverty_all.rename(columns={0: 'Below Poverty Line', 1: '< 200% Poverty Line', 2: '> 200% Poverty Line'})
poverty_all = poverty_all.rename(index={0: "All_Industries"})
poverty_all = poverty_all.drop('POVPIP')
poverty_all['Total'] = poverty_all['Below Poverty Line'] + poverty_all['< 200% Poverty Line'] + poverty_all['> 200% Poverty Line']

# %%
poverty_all
# Out:
#                 Below Poverty Line  < 200% Poverty Line  > 200% Poverty Line  Total
# All_Industries                2759                 3871                26682  33312

# %%
poverty = poverty.loc[poverty['INDP'].isin(frontline_industries)]
    
poverty_front = poverty.groupby(poverty['POVPIP']).size()
poverty_front = poverty_front.reset_index()
poverty_front = poverty_front.T
poverty_front = poverty_front.rename(columns={0: 'Below Poverty Line', 1: '< 200% Poverty Line', 2: '> 200% Poverty Line'})
poverty_front = poverty_front.rename(index={0: "Frontline_Industries"})
poverty_front = poverty_front.drop('POVPIP')
poverty_front['Total'] = poverty_front['Below Poverty Line'] + poverty_front['< 200% Poverty Line'] + poverty_front['> 200% Poverty Line']

# %%
poverty_front
# Out:
#                       Below Poverty Line  < 200% Poverty Line  > 200% Poverty Line  Total
# Frontline_Industries                 706                 1060                 5372   7138

# %%
#create dataframe for specific frontline industries
convert_industry_codes(poverty)
    
poverty = poverty.groupby(['INDP', 'POVPIP']).size()
poverty = poverty.unstack('POVPIP')
poverty.columns=['Below Poverty Line', '< 200% Poverty Line', '> 200% Poverty Line']
poverty.fillna(0, inplace = True)
poverty['Total'] = poverty['Below Poverty Line'] + poverty['< 200% Poverty Line'] + poverty['> 200% Poverty Line']

# %%
#combine dataframes
poverty_combined = pd.concat([poverty_all, poverty_front, poverty])
poverty_combined['Below Poverty Line'] = ((poverty_combined['Below Poverty Line'] / poverty_combined['Total']) * 100).apply(lambda x: round(x, 2))
poverty_combined['< 200% Poverty Line'] = ((poverty_combined['< 200% Poverty Line'] / poverty_combined['Total']) * 100).apply(lambda x: round(x, 2))
poverty_combined['> 200% Poverty Line'] = ((poverty_combined['> 200% Poverty Line'] / poverty_combined['Total']) * 100).apply(lambda x: round(x, 2))
poverty_combined = poverty_combined.reset_index()

poverty_final = pd.DataFrame(poverty_combined[['index', 'Total', 'Below Poverty Line', '< 200% Poverty Line', '> 200% Poverty Line']])
poverty_final.columns = ['Industry', 'Total', 'Below Poverty Line', '< 200% Poverty Line', '> 200% Poverty Line']

# %%
poverty_final
# Out:
#                Industry  Total  Below Poverty Line  < 200% Poverty Line  > 200% Poverty Line
# 0        All_Industries  33312                8.28                11.62                80.10
# 1  Frontline_Industries   7138                9.89                14.85                75.26
# 2     Building_Cleaning    261               20.31                24.52                55.17
# 3            Child_Care    796               12.81                17.96                69.22
# 4    Convenience_Stores   1275               12.31                16.86                70.82
# 5           Health_Care   4041                8.04                13.29                78.67
# 6        Postal_Service    589                7.81                11.54                80.65
# 7        Public_Transit    176               13.07                18.75                68.18

# %% [markdown]
# ## Educational Attainment (SCHL) ##

# %%
educ = popeduc[['SCHL', 'INDP']]

# %%
educ['SCHL'] = pd.to_numeric(educ['SCHL'])
educ.loc[educ['SCHL'] <= 11, 'SCHL'] = 0
educ.loc[educ['SCHL'] >= 22, 'SCHL'] = 4
educ.loc[educ['SCHL'] >= 20, 'SCHL'] = 3
educ.loc[educ['SCHL'] >= 18, 'SCHL'] = 2
educ.loc[educ['SCHL'] >= 12, 'SCHL'] = 1

educ_all = df.groupby(educ['SCHL']).size().reset_index()
educ_all = educ_all.T
educ_all = educ_all.rename(columns={0: 'Less than Highschool', 1: 'Highschool', 2: 'Some College', 3: 'College Degree', 4: 'Advanced Degree'})
educ_all = educ_all.rename(index={0: "All_Industries"})
educ_all = educ_all.drop('SCHL')
educ_all['Total'] = educ_all['Less than Highschool'] + educ_all['Highschool'] + educ_all['Some College'] + educ_all['College Degree'] + educ_all['Advanced Degree']

educ = educ.loc[educ['INDP'].isin(frontline_industries)]

educ_front = educ.groupby(educ['SCHL']).size()
educ_front = educ_front.reset_index()
educ_front = educ_front.T
educ_front = educ_front.rename(columns={0: 'Less than Highschool', 1: 'Highschool', 2: 'Some College', 3: 'College Degree', 4: 'Advanced Degree'})
educ_front = educ_front.rename(index={0: "Frontline_Industries"})
educ_front = educ_front.drop('SCHL')
educ_front['Total'] = educ_front['Less than Highschool'] + educ_front['Highschool'] + educ_front['Some College'] + educ_front['College Degree'] + educ_front['Advanced Degree']

convert_industry_codes(educ)

educ = educ.groupby(['INDP', 'SCHL']).size()
educ = educ.unstack('SCHL')
educ.columns=['Less than Highschool', 'Highschool', 'Some College', 'College Degree', 'Advanced Degree']
educ['Total'] = educ['Less than Highschool'] + educ['Highschool'] + educ['Some College'] + educ['College Degree'] + educ['Advanced Degree']

educ_combined = pd.concat([educ_all, educ_front, educ])

educ_combined['Less than Highschool'] = ((educ_combined['Less than Highschool'] / educ_combined['Total']) * 100).apply(lambda x: round(x, 2))
educ_combined['Highschool'] = ((educ_combined['Highschool'] / educ_combined['Total']) * 100).apply(lambda x: round(x, 2))
educ_combined['Some College'] = ((educ_combined['Some College'] / educ_combined['Total']) * 100).apply(lambda x: round(x, 2))
educ_combined['College Degree'] = ((educ_combined['College Degree'] / educ_combined['Total']) * 100).apply(lambda x: round(x, 2))
educ_combined['Advanced Degree'] = ((educ_combined['Advanced Degree'] / educ_combined['Total']) * 100).apply(lambda x: round(x, 2))

educ_combined = educ_combined.reset_index()

educ_final = pd.DataFrame(educ_combined[['index', 'Total', 'Less than Highschool', 'Highschool', 'Some College', 'College Degree', 'Advanced Degree']])
educ_final.columns = ['Industry', 'Total', 'Less than Highschool', 'Highschool', 'Some College', 'College Degree', 'Advanced Degree']
# Out:
# <ipython-input-27-6bcc0e0c90af>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# All_Industries                 191                    8987             659               24368  34205

# %%
racew = racew.loc[racew['INDP'].isin(frontline_industries)]

# %%
racew_front = racew.groupby(['RACWHT', 'HISP']).size().reset_index()
racew_front = racew_front.reset_index()
racew_front = racew_front.T
racew_front = racew_front.rename(columns={0: 'Non-White Hispanic', 1: 'Non-White Non-Hispanic', 2: 'White Hispanic', 3: 'White Non-Hispanic'})
racew_front = racew_front.rename(index={0: "Frontline_Industries"})
racew_front = racew_front.drop('index')
racew_front = racew_front.drop('RACWHT')
racew_front = racew_front.drop('HISP')
racew_front['Total'] = racew_front['Non-White Hispanic'] + racew_front['Non-White Non-Hispanic'] + racew_front['White Hispanic'] + racew_front['White Non-Hispanic']

# %%
racew_front
# Out:
#                       Non-White Hispanic  Non-White Non-Hispanic  White Hispanic  White Non-Hispanic  Total
# Frontline_Industries                  28                    2678             108                4418   7232

# %%
convert_industry_codes(racew)
# Out:
#        RACWHT  HISP                INDP
# 1           1     1  Convenience_Stores
# 3           0     1   Building_Cleaning
# 9           0     1         Health_Care
# 13          1     1      Postal_Service
# 14          1     1          Child_Care
# ...       ...   ...                 ...
# 34185       0     1  Convenience_Stores
# 34194       1     1      Postal_Service
# 34202       1     1  Convenience_Stores
# 34203       0     1      Postal_Service
# 34204       0     1         Health_Care
#
# [7232 rows x 3 columns]

# %%
racew = racew.groupby(['INDP', 'RACWHT', 'HISP']).size()

# %%
racew = racew.unstack('RACWHT')
racew = racew.unstack('HISP')

# %%
racew.columns=['Non-White Hispanic', 'Non-White Non-Hispanic', 'White Hispanic', 'White Non-Hispanic']
racew.fillna(0, inplace = True)
racew['Total'] = racew['Non-White Hispanic'] + racew['Non-White Non-Hispanic'] + racew['White Hispanic'] + racew['White Non-Hispanic']
racew = racew.astype(int)

# %%
racew
# Out:
#                     Non-White Hispanic  Non-White Non-Hispanic  White Hispanic  White Non-Hispanic  Total
# INDP
# Building_Cleaning                    5                     120               5                 137    267
# Child_Care                           4                     325               8                 465    802
# Convenience_Stores                   3                     417              27                 865   1312
# Health_Care                         15                    1443              63                2562   4083
# Postal_Service                       1                     243               4                 344    592
# Public_Transit                       0                     130               1                  45    176

# %%
racew_all = racew_all.astype(int)
racew_front = racew_front.astype(int)

# %%
racew_combined = pd.concat([racew_all, racew_front, racew])

# %%
racew_combined['Non-White Hispanic'] = ((racew_combined['Non-White Hispanic'] / racew_combined['Total']) * 100).apply(lambda x: round(x, 2))
racew_combined['Non-White Non-Hispanic'] = ((racew_combined['Non-White Non-Hispanic'] / racew_combined['Total']) * 100).apply(lambda x: round(x, 2))
racew_combined['White Hispanic'] = ((racew_combined['White Hispanic'] / racew_combined['Total']) * 100).apply(lambda x: round(x, 2))
racew_combined['White Non-Hispanic'] = ((racew_combined['White Non-Hispanic'] / racew_combined['Total']) * 100).apply(lambda x: round(x, 2))

# %%
racew_combined = racew_combined.reset_index()

# %%
racew_combined
# Out:
#                   index  Non-White Hispanic  Non-White Non-Hispanic  White Hispanic  White Non-Hispanic  Total
# 0        All_Industries                0.56                   26.27            1.93               71.24  34205
# 1  Frontline_Industries                0.39                   37.03            1.49               61.09   7232
# 2     Building_Cleaning                1.87                   44.94            1.87               51.31    267
# 3            Child_Care                0.50                   40.52            1.00               57.98    802
# 4    Convenience_Stores                0.23                   31.78            2.06               65.93   1312
# 5           Health_Care                0.37                   35.34            1.54               62.75   4083
# 6        Postal_Service                0.17                   41.05            0.68               58.11    592
# ...

# %% [markdown]
# ## Race Black (RACBLK) ##

# %%
raceblack = popraceblack[['RACBLK','INDP']]
raceblack_df =  format_dataframes(raceblack, 'RACBLK', 'Non-Black', 'Black')

# %%
raceblack_df[3]
# Out:
#                Industry  Total  % Non-Black  % Black
# 0        All_Industries  34205        77.38    22.62
# 1  Frontline_Industries   7232        66.68    33.32
# 2     Building_Cleaning    267        55.81    44.19
# 3            Child_Care    802        60.72    39.28
# 4    Convenience_Stores   1312        71.42    28.58
# 5           Health_Care   4083        69.78    30.22
# 6        Postal_Service    592        59.63    40.37
# 7        Public_Transit    176        26.70    73.30

# %% [markdown]
# ## Race Other (RACSOR) ##

# %%
raceother = popraceother[['RACSOR','INDP']]
raceother_df =  format_dataframes(raceother, 'RACSOR', 'Not-Other', 'Other')

# %%
raceother_df[3]
# Out:
#                Industry  Total  % Not-Other  % Other
# 0        All_Industries  34205        99.31     0.69
# 1  Frontline_Industries   7232        99.49     0.51
# 2     Building_Cleaning    267        98.13     1.87
# 3            Child_Care    802        99.63     0.37
# 4    Convenience_Stores   1312        99.24     0.76
# 5           Health_Care   4083        99.61     0.39
# 6        Postal_Service    592        99.66     0.34
# 7        Public_Transit    176        99.43     0.57

# %% [markdown]
# ## Race Native American/Alaska Native (RACAIAN) ##

# %%
racenative = popracenative[['RACAIAN','INDP']]
racenative_df =  format_dataframes(racenative, 'RACAIAN', 'Not-Native', 'Native Indian or Alaskan')

# %%
racenative_df[3]
# Out:
#                Industry  Total  % Not-Native  % Native Indian or Alaskan
# 0        All_Industries  34205         99.27                        0.73
# 1  Frontline_Industries   7232         99.23                        0.77
# 2     Building_Cleaning    267         98.88                        1.12
# 3            Child_Care    802         99.25                        0.75
# 4    Convenience_Stores   1312         98.78                        1.22
# 5           Health_Care   4083         99.44                        0.56
# 6        Postal_Service    592         98.82                        1.18
# 7        Public_Transit    176         99.43                        0.57

# %% [markdown]
# ## Race Hawaiian (RACNH) ##

# %%
racehawaii = popracehawaii[['RACNH','INDP']]
racehawaii_df =  format_dataframes(racehawaii, 'RACNH', 'Not-AAPI', 'AAPI')

# %%
racehawaii_df[3]
# Out:
#                Industry    Total  % Not-AAPI  % AAPI
# 0        All_Industries    34205       99.97    0.03
# 1  Frontline_Industries     7232       99.94    0.06
# 2     Building_Cleaning  2.7e+02      100.00    0.00
# 3            Child_Care    8e+02       99.88    0.12
# 4    Convenience_Stores  1.3e+03      100.00    0.00
# 5           Health_Care  4.1e+03       99.93    0.07
# 6        Postal_Service  5.9e+02      100.00    0.00
# 7        Public_Transit  1.8e+02      100.00    0.00

# %% [markdown]
# ## Race Pacific Islander (RACPI) ##

# %%
racepacific = popracepacific[['RACPI','INDP']]
racepacific_df =  format_dataframes(racepacific, 'RACPI', 'Not-AAPI', 'AAPI')

# %%
racepacific_df[3]
# Out:
#                Industry    Total  % Not-AAPI  % AAPI
# 0        All_Industries    34205       99.92    0.08
# 1  Frontline_Industries     7232       99.89    0.11
# 2     Building_Cleaning  2.7e+02      100.00    0.00
# 3            Child_Care    8e+02      100.00    0.00
# 4    Convenience_Stores  1.3e+03       99.85    0.15
# 5           Health_Care  4.1e+03       99.90    0.10
# 6        Postal_Service  5.9e+02       99.66    0.34
# 7        Public_Transit  1.8e+02      100.00    0.00

# %% [markdown]
# ## Race Asian (RACASN) ##

# %%
raceasian = popraceasian[['RACASN','INDP']]
raceasian_df =  format_dataframes(raceasian, 'RACASN', 'Not-AAPI', 'AAPI')

# %%
raceasian_df[3]
# Out:
#                Industry    Total  % Not-AAPI  % AAPI
# 0        All_Industries    34205       95.52    4.48
# 1  Frontline_Industries     7232       95.67    4.33
# 2     Building_Cleaning  2.7e+02       98.88    1.12
# 3            Child_Care    8e+02       97.88    2.12
# 4    Convenience_Stores  1.3e+03       95.81    4.19
# 5           Health_Care  4.1e+03       94.44    5.56
# 6        Postal_Service  5.9e+02       98.14    1.86
# 7        Public_Transit  1.8e+02      100.00    0.00

# %% [markdown]
# ## AAPI (RACASN/RACPI/RACNH)##

# %%
raceAAPI_all = pd.concat([raceasian_df[0]['AAPI'], racehawaii_df[0]['AAPI'], racepacific_df[0]['AAPI']], axis=1, keys=['asian', 'hawaii', 'pacific'])
raceAAPI_all['AAPI'] = raceAAPI_all['asian'] + raceAAPI_all['hawaii'] + raceAAPI_all['pacific']
raceAAPI_all['Total'] = raceasian_df[0]['Total']
raceAAPI_all = raceAAPI_all[['AAPI', 'Total']]

raceAAPI_front = pd.concat([raceasian_df[1]['AAPI'], racehawaii_df[1]['AAPI'], racepacific_df[1]['AAPI']], axis=1, keys=['asian', 'hawaii', 'pacific'])
raceAAPI_front['AAPI'] = raceAAPI_front['asian'] + raceAAPI_front['hawaii'] + raceAAPI_front['pacific']
raceAAPI_front['Total'] = raceasian_df[1]['Total']
raceAAPI_front = raceAAPI_front[['AAPI', 'Total']]

raceAAPI = pd.concat([raceasian_df[2]['AAPI'], racehawaii_df[2]['AAPI'], racepacific_df[2]['AAPI']], axis=1, keys=['asian', 'hawaii', 'pacific'])
raceAAPI['AAPI'] = raceAAPI['asian'] + raceAAPI['hawaii'] + raceAAPI['pacific']
raceAAPI['Total'] = raceasian_df[2]['Total']
raceAAPI = raceAAPI[['AAPI', 'Total']]

raceAAPI_combined = pd.concat([raceAAPI_all, raceAAPI_front, raceAAPI])
raceAAPI_combined = raceAAPI_combined.astype(int)
raceAAPI_combined['AAPI'] = ((raceAAPI_combined['AAPI'] / raceAAPI_combined['Total']) * 100).apply(lambda x: round(x, 2))

raceAAPI_final = raceAAPI_combined.reset_index()
raceAAPI_final = raceAAPI_final.rename(columns={'index': 'Industry'})

raceAAPI_final
# Out:
#                Industry  AAPI  Total
# 0        All_Industries  4.60  34205
# 1  Frontline_Industries  4.49   7232
# 2     Building_Cleaning  1.12    267
# 3            Child_Care  2.24    802
# 4    Convenience_Stores  4.34   1312
# 5           Health_Care  5.73   4083
# 6        Postal_Service  2.20    592
# 7        Public_Transit  0.00    176

# %%
race_frame = {'Industry': raceblack_df[3]['Industry']
         , 'Total': raceblack_df[3]['Total']
         , 'White': racew_combined['White Non-Hispanic']
         , 'Black': raceblack_df[3]['% Black']
         , 'Hispanic': racew_combined['White Hispanic']
         , 'AAPI': raceAAPI_final['AAPI']
         , 'Other': raceother_df[3]['% Other']}

# %%
race_final = pd.DataFrame(race_frame)

# %%
race_final
# Out:
#                Industry  Total  White  Black  Hispanic  AAPI  Other
# 0        All_Industries  34205  71.24  22.62      1.93  4.60   0.69
# 1  Frontline_Industries   7232  61.09  33.32      1.49  4.49   0.51
# 2     Building_Cleaning    267  51.31  44.19      1.87  1.12   1.87
# 3            Child_Care    802  57.98  39.28      1.00  2.24   0.37
# 4    Convenience_Stores   1312  65.93  28.58      2.06  4.34   0.76
# 5           Health_Care   4083  62.75  30.22      1.54  5.73   0.39
# 6        Postal_Service    592  58.11  40.37      0.68  2.20   0.34
# 7        Public_Transit    176  25.57  73.30      0.57  0.00   0.57

# %%
frame = {'Industry': raceblack_df[3]['Industry']
        , 'Total': gender_df[3]['Total']
        , 'Female': gender_df[3]['% Female']
        , 'Foreign Born': fborn_df[3]['% Foreign Born']
        , 'Age 50+': age_df[3]['% 50+']
        , 'Home Ownership': homeowner_df[3]['% Home Owner']
        , 'Public Transit Commute': trans_df[3]['% Public Transportation']
        , 'Full-time': work_df[3]['% Full-Time']
        , 'Part-time': work_df[3]['% Part-Time']
        , 'White': racew_combined['White Non-Hispanic']
        , 'Black': raceblack_df[3]['% Black']
        , 'Hispanic': racew_combined['White Hispanic']
        , 'AAPI': raceAAPI_final['AAPI']
        , 'Other': raceother_df[3]['% Other']
        , 'Less than High School': educ_final['Less than Highschool']
        , 'High School': educ_final['Highschool']
        , 'Some College': educ_final['Some College']
        , 'College': educ_final['College Degree']
        , 'Advanced': educ_final['Advanced Degree']
        , 'Below poverty line': poverty_final['Below Poverty Line']
        , '<200% poverty line': poverty_final['< 200% Poverty Line']
        , 'No Health Insurance': insurance_df[3]['% Uninsured']
        , 'Child in home': child_df[3]['% 1+ children']
        , 'Senior (age 65+) in home': senior_df[3]['% Senior (age 65+) in home']
        }

# %%
stl_df = pd.DataFrame(frame)

# %%
stl_df = stl_df.T

# %%
stl_df = stl_df.drop('Industry')

# %%
stl_df = stl_df.rename(columns={0: 'All Workers'
                                , 1: 'All Frontline Industries'
                                , 2:'Grocery, Convenience, & Drug Stores'
                                , 3: 'Public Transit', 4:'Trucking, Warehouse, & Postal Service'
                                , 5:'Building Cleaning Services'
                                , 6:'Health Care'
                                , 7:'Childcare & Social Services'})
stl_df = stl_df.rename(index={'Total': 'All Workers(16+)'})

# %%
stl_df
# Out:
#                          All Workers All Frontline Industries Grocery, Convenience, & Drug Stores Public Transit Trucking, Warehouse, & Postal Service Building Cleaning Services Health Care Childcare & Social Services
# All Workers(16+)               34205                     7232                                 267            802                                  1312                       4083         592                         176
# Female                            51                       66                                  45             86                                    50                         75          29                          49
# Foreign Born                     8.5                      8.9                                  10            5.5                                   7.9                        9.9          11                         2.3
# ...
