# %%
import pandas as pd
import requests

from pprint import pprint
from resources.api_keys import census_api_key

pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)
pd.options.display.max_columns = None
pd.options.display.max_rows = 25

# %%
get_data = requests.get('https://api.census.gov/data/2018/acs/acs5/pums?get=SEX,INDP,HICOV&ucgid=7950000US1700401,7950000US1700501,7950000US1701001,7950000US1701104,7950000US1701105,7950000US1701204,7950000US1701205,7950000US2900400,7950000US2901600,7950000US2901701,7950000US2901702,7950000US2901703,7950000US2901801,7950000US2901802,7950000US2901803,7950000US2901804,7950000US2901805,7950000US2901806,7950000US2901807,7950000US2901808,7950000US2901901,7950000US2901902,7950000US2902001,7950000US2902002').json()

# %%
df = pd.DataFrame(get_data, columns=get_data.pop(0))

# %%
convert_dt = df

# %%
for column in convert_dt.columns:
    df[column] = df[column].astype(int)

# %%
convert_to_int
# Out:
#         SEX  INDP  HICOV  PUMA  ST
# 0         2  8191      1  1205  17
# 1         2   169      1  1808  29
# 2         1  8191      1  1808  29
# 3         2   169      1  1808  29
# 4         2   169      1  1808  29
# ...     ...   ...    ...   ...  ..
# 154139    2   169      1  1204  17
# 154140    1   169      1  1105  17
# 154141    2   169      1  1105  17
# 154142    1  8870      1   401  17
# 154143    1   169      1  2002  29
#
# [154144 rows x 5 columns]

# %%
frontline = convert_dt[convert_dt['INDP'].isin([4470, 4971, 4972, 5070, 5391, 6080, 6180, 6170, 6390, 6370,7690, 7970, 8090, 8170, 8180, 8191, 8192, 8270, 8290, 8370, 8380, 8470])]

# %%
frontline.reset_index(drop=True, inplace = True)

# %%
frontline
# Out:
#        SEX  INDP  HICOV  PUMA  ST
# 0        2  8191      1  1205  17
# 1        1  8191      1  1808  29
# 2        2  8090      1  1701  29
# 3        1  8090      1  1701  29
# 4        2  8191      1  1104  17
# ...    ...   ...    ...   ...  ..
# 19480    2  8191      1   401  17
# 19481    2  6170      1  1104  17
# 19482    2  8191      1   401  17
# 19483    1  6170      1  1804  29
# 19484    2  8191      1  1804  29
#
# [19485 rows x 5 columns]

# %% [markdown]
# ##### DataFrame.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad') ######

# %%
PUMA = frontline.set_index(['PUMA','ST'])

# %%
PUMA.sort_index(inplace = True)

# %%
PUMA
# Out:
#          SEX  INDP  HICOV
# PUMA ST
# 400  29    2  8170      1
#      29    2  8191      1
#      29    1  4971      1
#      29    1  8180      2
#      29    2  6370      2
#      29    2  8370      1
#      29    2  5391      1
#      29    2  8270      1
#      29    2  5391      1
#      29    1  6170      1
#      29    2  8191      1
#      29    2  5070      1
#      29    1  5391      1
#      29    2  7970      1
#      29    2  8170      1
#      29    1  5391      1
#      29    2  8170      1
#      29    1  4971      1
#      29    1  8270      1
#      29    2  8270      1
#      29    2  4971      1
#      29    2  4971      1
#      29    1  4971      2
#      29    2  5070      1
#      29    2  8370      2
#      29    2  8191      1
#      29    2  5070      1
#      29    1  6080      1
#      29    2  7690      2
#      29    1  8191      1
#      29    2  8170      1
#      29    2  8090      1
#      29    2  8270      1
#      29    1  8270      1
# ...
